# %%
from pathlib import Path
import os

# %%
path = Path("C:/temp_HBVH_files/")

# %%
if not path.exists():
    os.mkdir(path)

# %%
import pandas as pd

pd.to_datetime("2020-01-01", utc=True)
# Out:
# Timestamp('2020-01-01 00:00:00+0000', tz='UTC')
