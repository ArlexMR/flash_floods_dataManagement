# %%
import pandas as pd 
import xarray as xarray
import numpy as numpy
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %%
report_file = Path("../sample_data/report_20260819132019.csv")


pd.read_csv(report_file)
# Out:
#    Unnamed: 0                 start_date                   end_date  tot_nan  \
# 0     1011000  1987-12-02 05:00:00+00:00  2026-04-01 00:00:00+00:00    14679
# 1     1013500  1990-10-01 05:00:00+00:00  2026-05-05 00:00:00+00:00     9792
# 2     1022500  1989-10-01 04:15:00+00:00  2025-05-05 00:00:00+00:00        0
# 3     1030500  1989-10-01 04:15:00+00:00  2025-05-05 00:00:00+00:00        0
# 4     1031500  1987-11-05 05:15:00+00:00  2026-03-04 14:30:00+00:00        0
# 5     1047000  1987-10-01 04:15:00+00:00  2026-01-29 00:00:00+00:00     6469
# 6     1055000  1990-10-01 04:15:00+00:00  2026-05-05 00:00:00+00:00        0
# 7     1078000  1990-10-11 04:00:00+00:00  2026-05-15 00:00:00+00:00        0
# 8     1093852  1994-06-17 04:00:00+00:00  2024-07-29 00:00:00+00:00        0
# 9     1119500  1990-10-01 05:30:00+00:00  2026-05-05 00:00:00+00:00        0
#
#    frac_nan
# 0  0.019411
# 1  0.011353
# 2  0.000000
# 3  0.000000
# 4  0.000000
# 5  0.007488
# 6  0.000000
# 7  0.000000
# ...

# %%
aorc_path = Path("../AORC_data")

files = list(aorc_path.iterdir())
variables = set([file.name[:-9] for file in files])
# Out:
# {'APCP_surface',
#  'DLWRF_surface',
#  'DSWRF_surface',
#  'PRES_surface',
#  'SPFH_2maboveground',
#  'TMP_2maboveground',
#  'UGRD_10maboveground',
#  'VGRD_10maboveground'}

# %%
len(usgs_data_path.iterdir())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 len(usgs_data_path.iterdir())
#
# TypeError: object of type 'generator' has no len()

# %%
(5+1)%5
# Out:
# 1
